# %%
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_rows = None
import numpy as np

# %%
df = pd.read_parquet('../../data/train_data.parquet')
df['S_2'] = pd.to_datetime(df['S_2'])

# %%
df.info(verbose = True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5531451 entries, 0 to 5531450
# Data columns (total 191 columns):
#  #    Column       Non-Null Count    Dtype
# ---   ------       --------------    -----
#  0    customer_ID  5531451 non-null  object
#  1    S_2          5531451 non-null  datetime64[ns]
#  2    P_2          5485466 non-null  float32
#  3    D_39         5531451 non-null  float32
#  4    B_1          5531451 non-null  float32
#  5    B_2          5529435 non-null  float32
#  6    R_1          5531451 non-null  float32
#  7    S_3          4510907 non-null  float32
#  8    D_41         5529435 non-null  float32
#  9    B_3          5529435 non-null  float32
#  10   D_42         791314 non-null   float32
#  11   D_43         3873055 non-null  float32
#  12   D_44         5257132 non-null  float32
#  13   B_4          5531451 non-null  float32
#  14   D_45         5529434 non-null  float32
#  15   B_5          5531451 non-null  float32
# ...

# %%
df.head()
# Out:
#                                          customer_ID        S_2       P_2  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-03-09  0.938469
# 1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-04-07  0.936665
# 2  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-05-28  0.954180
# 3  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-06-13  0.960384
# 4  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-07-16  0.947248
#
#        D_39       B_1       B_2       R_1       S_3      D_41       B_3  D_42  \
# 0  0.001733  0.008724  1.006838  0.009228  0.124035  0.008771  0.004709   NaN
# 1  0.005775  0.004923  1.000653  0.006151  0.126750  0.000798  0.002714   NaN
# 2  0.091505  0.021655  1.009672  0.006815  0.123977  0.007598  0.009423   NaN
# 3  0.002455  0.013683  1.002700  0.001373  0.117169  0.000685  0.005531   NaN
# 4  0.002483  0.015193  1.000727  0.007605  0.117325  0.004653  0.009312   NaN
#
# ...

# %%
df['end_of_month'] = df['S_2'] + pd.offsets.MonthEnd(0)

# %%
df['end_of_month'].value_counts()
# Out:
# end_of_month
# 2018-03-31    458913
# 2018-02-28    452781
# 2018-01-31    446255
# 2017-12-31    438910
# 2017-11-30    434268
# 2017-10-31    430292
# 2017-09-30    425455
# 2017-08-31    421099
# 2017-07-31    415602
# 2017-06-30    410384
# 2017-04-30    401556
# 2017-05-31    400306
# 2017-03-31    395630
# Name: count, dtype: int64

# %%
df.sort_values(by = ['customer_ID', 'end_of_month'], inplace = True)
df[['customer_ID', 'end_of_month', 'target']]

# %%
df_test = df[df['end_of_month'] == '2018-03-31']

# %%
df_test['target'].value_counts()
# Out:
# target
# 0    340085
# 1    118828
# Name: count, dtype: int64

# %%
df['target'].value_counts()
# Out:
# target
# 0    4153582
# 1    1377869
# Name: count, dtype: int64

# %%
train_dates = ['2017-03-31 00:00:00', '2017-04-30 00:00:00', '2017-05-31 00:00:00',
 '2017-06-30 00:00:00', '2017-07-31 00:00:00', '2017-08-31 00:00:00',
 '2017-09-30 00:00:00', '2017-10-31 00:00:00', '2017-11-30 00:00:00',
 '2017-12-31 00:00:00', '2018-01-31 00:00:00', '2018-02-28 00:00:00']

test_dates = ['2017-04-30 00:00:00', '2017-05-31 00:00:00',
 '2017-06-30 00:00:00', '2017-07-31 00:00:00', '2017-08-31 00:00:00',
 '2017-09-30 00:00:00', '2017-10-31 00:00:00', '2017-11-30 00:00:00',
 '2017-12-31 00:00:00', '2018-01-31 00:00:00', '2018-02-28 00:00:00',
 '2018-03-31 00:00:00']

# %%
df_train = df[df['end_of_month'].isin(train_dates)]
df_test = df[df['end_of_month'].isin(test_dates)]
# Out:
# C:\Users\vaseekaranv\AppData\Local\Temp\ipykernel_18512\337454229.py:1: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   df_train = df[df['end_of_month'].isin(train_dates)]
# C:\Users\vaseekaranv\AppData\Local\Temp\ipykernel_18512\337454229.py:2: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   df_test = df[df['end_of_month'].isin(test_dates)]

# %%
df_test.end_of_month.value_counts()
# Out:
# end_of_month
# 2018-03-31    458913
# 2018-02-28    452781
# 2018-01-31    446255
# 2017-12-31    438910
# 2017-11-30    434268
# 2017-10-31    430292
# 2017-09-30    425455
# 2017-08-31    421099
# 2017-07-31    415602
# 2017-06-30    410384
# 2017-04-30    401556
# 2017-05-31    400306
# Name: count, dtype: int64

# %%
#Function to return the df with ids for all 7 months
def get_df_ids_all_months(df, customer_id_col = 'customer_ID', date_col = 'end_of_month', num_of_months = 12):
    customer_counts = df.groupby(customer_id_col)[date_col].nunique()
    customer_ids_all_dates = customer_counts[customer_counts == num_of_months].index
    return df[df[customer_id_col].isin(customer_ids_all_dates)]

# %%
df_train_all_dates = get_df_ids_all_months(df_train)
df_test_all_dates = get_df_ids_all_months(df_test)

# %%
df_train_all_dates['customer_ID'].nunique()
# Out:
# 386034

# %%
df_test_all_dates['customer_ID'].nunique()
# Out:
# 391349

# %%
df_train_all_dates.to_parquet('../../data/train_data_12months_unprocessed.parquet', index = False)
df_test_all_dates.to_parquet('../../data/test_data_12months_unprocessed.parquet', index = False)

# %%
df_train_all_dates = pd.read_parquet('../../data/train_data_12months_unprocessed.parquet')
df_test_all_dates = pd.read_parquet('../../data/test_data_12months_unprocessed.parquet')

# %%
df_train_all_dates.info(verbose = True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4632408 entries, 0 to 4632407
# Data columns (total 192 columns):
#  #    Column        Non-Null Count    Dtype
# ---   ------        --------------    -----
#  0    customer_ID   4632408 non-null  object
#  1    S_2           4632408 non-null  datetime64[ns]
#  2    P_2           4612598 non-null  float32
#  3    D_39          4632408 non-null  float32
#  4    B_1           4632408 non-null  float32
#  5    B_2           4632215 non-null  float32
#  6    R_1           4632408 non-null  float32
#  7    S_3           3753056 non-null  float32
#  8    D_41          4632215 non-null  float32
#  9    B_3           4632215 non-null  float32
#  10   D_42          405865 non-null   float32
#  11   D_43          3326263 non-null  float32
#  12   D_44          4419744 non-null  float32
#  13   B_4           4632408 non-null  float32
#  14   D_45          4632215 non-null  float32
#  15   B_5           4632408 non-null  float32
# ...

# %%
df_train_all_dates['end_of_month'].value_counts()
# Out:
# end_of_month
# 2017-03-31    386034
# 2017-04-30    386034
# 2017-05-31    386034
# 2017-06-30    386034
# 2017-07-31    386034
# 2017-08-31    386034
# 2017-09-30    386034
# 2017-10-31    386034
# 2017-11-30    386034
# 2017-12-31    386034
# 2018-01-31    386034
# 2018-02-28    386034
# Name: count, dtype: int64

# %%
#Keeping columns that are not null at the last input month of the training data
non_null_cols = df_train_all_dates[df_train_all_dates['end_of_month'] == '2018-02-28'].dropna(axis = 1).columns
non_null_cols
# Out:
# Index(['customer_ID', 'S_2', 'D_39', 'B_1', 'B_2', 'R_1', 'D_41', 'B_3', 'B_4',
#        'D_45', 'B_5', 'R_2', 'D_47', 'B_6', 'B_7', 'D_51', 'B_9', 'R_3',
#        'B_10', 'S_5', 'B_11', 'S_6', 'D_54', 'R_4', 'B_12', 'S_8', 'B_13',
#        'R_5', 'D_58', 'B_14', 'D_60', 'S_11', 'D_63', 'D_65', 'B_16', 'B_18',
#        'B_19', 'B_20', 'S_12', 'R_6', 'S_13', 'B_21', 'B_22', 'D_71', 'S_15',
#        'B_23', 'P_4', 'D_75', 'B_24', 'R_7', 'B_26', 'R_8', 'S_16', 'R_10',
#        'R_11', 'B_27', 'S_17', 'R_12', 'B_28', 'R_13', 'R_14', 'R_15', 'R_16',
#        'B_30', 'S_18', 'D_86', 'R_17', 'R_18', 'B_31', 'S_19', 'R_19', 'B_32',
#        'S_20', 'R_20', 'R_21', 'B_33', 'R_22', 'R_23', 'D_92', 'D_93', 'D_94',
#        'R_24', 'R_25', 'D_96', 'D_102', 'B_36', 'B_38', 'D_126', 'D_127',
#        'D_133', 'R_28', 'D_140', 'D_144', 'target', 'end_of_month'],
#       dtype='object')

# %%
df_train_all_dates[non_null_cols].info(verbose = True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4632408 entries, 0 to 4632407
# Data columns (total 95 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   customer_ID   4632408 non-null  object
#  1   S_2           4632408 non-null  datetime64[ns]
#  2   D_39          4632408 non-null  float32
#  3   B_1           4632408 non-null  float32
#  4   B_2           4632215 non-null  float32
#  5   R_1           4632408 non-null  float32
#  6   D_41          4632215 non-null  float32
#  7   B_3           4632215 non-null  float32
#  8   B_4           4632408 non-null  float32
#  9   D_45          4632215 non-null  float32
#  10  B_5           4632408 non-null  float32
#  11  R_2           4632408 non-null  float32
#  12  D_47          4632408 non-null  float32
#  13  B_6           4632408 non-null  float32
#  14  B_7           4632408 non-null  float32
#  15  D_51          4632408 non-null  float32
# ...

# %%
df_test_all_dates[non_null_cols].info(verbose = True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4696188 entries, 0 to 4696187
# Data columns (total 95 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   customer_ID   4696188 non-null  object
#  1   S_2           4696188 non-null  datetime64[ns]
#  2   D_39          4696188 non-null  float32
#  3   B_1           4696188 non-null  float32
#  4   B_2           4696036 non-null  float32
#  5   R_1           4696188 non-null  float32
#  6   D_41          4696036 non-null  float32
#  7   B_3           4696036 non-null  float32
#  8   B_4           4696188 non-null  float32
#  9   D_45          4696036 non-null  float32
#  10  B_5           4696188 non-null  float32
#  11  R_2           4696188 non-null  float32
#  12  D_47          4696188 non-null  float32
#  13  B_6           4696188 non-null  float32
#  14  B_7           4696188 non-null  float32
#  15  D_51          4696188 non-null  float32
# ...

# %%
#Saving the unprocessed non-null dfs
df_train_all_dates[non_null_cols].to_parquet('../../data/non-null/train_data_12_months_unprocessed_non_null.parquet', index = False)
df_test_all_dates[non_null_cols].to_parquet('../../data/non-null/test_data_12_months_unprocessed_non_null.parquet', index = False)

# %%
df_train_all_dates[non_null_cols].isna().sum()
# Out:
# customer_ID         0
# S_2                 0
# D_39                0
# B_1                 0
# B_2               193
# R_1                 0
# D_41              193
# B_3               193
# B_4                 0
# D_45              193
# B_5                 0
# R_2                 0
# D_47                0
# B_6                 0
# B_7                 0
# D_51                0
# B_9                 0
# R_3                 0
# B_10                0
# S_5                 0
# B_11                0
# S_6                 0
# D_54              193
# R_4                 0
# B_12                0
# S_8                 0
# B_13             7925
# R_5                 0
# D_58                0
# B_14                0
# D_60                0
# S_11                0
# D_63                0
# D_65                0
# B_16              193
# B_18                0
# B_19              193
# B_20              193
# S_12                0
# R_6                 0
# S_13                0
# ...

# %%
df['end_of_month'].unique()
# Out:
# <DatetimeArray>
# ['2017-03-31 00:00:00', '2017-04-30 00:00:00', '2017-05-31 00:00:00',
#  '2017-06-30 00:00:00', '2017-07-31 00:00:00', '2017-08-31 00:00:00',
#  '2017-09-30 00:00:00', '2017-10-31 00:00:00', '2017-11-30 00:00:00',
#  '2017-12-31 00:00:00', '2018-01-31 00:00:00', '2018-02-28 00:00:00',
#  '2018-03-31 00:00:00']
# Length: 13, dtype: datetime64[ns]

# %%
df['end_of_month'].value_counts()
# Out:
# end_of_month
# 2018-03-31    458913
# 2018-02-28    452781
# 2018-01-31    446255
# 2017-12-31    438910
# 2017-11-30    434268
# 2017-10-31    430292
# 2017-09-30    425455
# 2017-08-31    421099
# 2017-07-31    415602
# 2017-06-30    410384
# 2017-04-30    401556
# 2017-05-31    400306
# 2017-03-31    395630
# Name: count, dtype: int64

# %%
df_test.isna().sum()
# Out:
# customer_ID        0
# S_2                0
# P_2             2969
# D_39               0
# B_1                0
#                 ...
# D_145           2830
# target             0
# month              0
# year               0
# end_of_month       0
# Length: 194, dtype: int64

# %%
df_test.info(show_counts=True, verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 458913 entries, 12 to 5531450
# Data columns (total 194 columns):
#  #    Column        Non-Null Count   Dtype
# ---   ------        --------------   -----
#  0    customer_ID   458913 non-null  object
#  1    S_2           458913 non-null  datetime64[ns]
#  2    P_2           455944 non-null  float32
#  3    D_39          458913 non-null  float32
#  4    B_1           458913 non-null  float32
#  5    B_2           458882 non-null  float32
#  6    R_1           458913 non-null  float32
#  7    S_3           373943 non-null  float32
#  8    D_41          458882 non-null  float32
#  9    B_3           458882 non-null  float32
#  10   D_42          59910 non-null   float32
#  11   D_43          324591 non-null  float32
#  12   D_44          436618 non-null  float32
#  13   B_4           458913 non-null  float32
#  14   D_45          458882 non-null  float32
#  15   B_5           458913 non-null  float32
# ...

# %%
df_test[['B_30', 'B_38', 'D_114', 'D_116', 'D_117', 'D_120', 'D_126', 'D_63', 'D_64', 'D_66', 'D_68']].info(show_counts=True, verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 458913 entries, 12 to 5531450
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   B_30    458882 non-null  float32
#  1   B_38    458882 non-null  float32
#  2   D_114   452896 non-null  float32
#  3   D_116   452896 non-null  float32
#  4   D_117   452896 non-null  float32
#  5   D_120   452896 non-null  float32
#  6   D_126   458913 non-null  float32
#  7   D_63    458913 non-null  object
#  8   D_64    448876 non-null  object
#  9   D_66    52582 non-null   float32
#  10  D_68    449901 non-null  float32
# dtypes: float32(9), object(2)
# memory usage: 26.3+ MB
