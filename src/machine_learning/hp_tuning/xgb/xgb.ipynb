# %%
import pandas as pd
import numpy as np
from sklearnex import patch_sklearn
patch_sklearn()

import sys
import os
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
# Setting path to load util functions
from pathlib import Path
parent_dir = Path.cwd().parents[3]
sys.path.append(os.path.abspath(parent_dir))

# %%
train_df = pd.read_parquet('../../../../data/final_features_ml/train_all_features_last_month.parquet')
val_df = pd.read_parquet('../../../../data/final_features_ml/val_all_features_last_month.parquet')
test_df = pd.read_parquet('../../../../data/final_features_ml/test_all_features_last_month.parquet')

y_train = pd.read_parquet('../../../../data/3d_array/train_targets.parquet')
y_val = pd.read_parquet('../../../../data/3d_array/val_targets.parquet')
y_test = pd.read_parquet('../../../../data/3d_array/test_targets.parquet')

# %%
train_df.sort_values(by = ['customer_ID'], inplace=True)
y_train.sort_values(by = ['customer_ID'], inplace=True)
val_df.sort_values(by = ['customer_ID'], inplace=True)
y_val.sort_values(by = ['customer_ID'], inplace=True)
test_df.sort_values(by = ['customer_ID'], inplace=True)
y_test.sort_values(by = ['customer_ID'], inplace=True)

# %%
train_df.shape, y_train.shape, val_df.shape, y_val.shape, test_df.shape, y_test.shape
# Out:
# ((289115, 426),
#  (289115, 3),
#  (32124, 426),
#  (32124, 3),
#  (137674, 426),
#  (137674, 3))

# %%
train_df.reset_index(drop=True, inplace=True)
y_train.reset_index(drop=True, inplace=True)
val_df.reset_index(drop=True, inplace=True)
y_val.reset_index(drop=True, inplace=True)
test_df.reset_index(drop=True, inplace=True)
y_test.reset_index(drop=True, inplace=True)

# %%
import time
from hyperopt import fmin, tpe, hp, STATUS_OK, STATUS_FAIL, Trials, space_eval
from sklearn.metrics import recall_score, classification_report
from sklearn.base import ClassifierMixin # To ensure model has fit/predict
from typing import Dict, Any, Type, Tuple

import mlflow
from utils.threshold import find_threshold_binary_search

# Define types for clarity (optional but good practice)
DataType = Tuple[pd.DataFrame | np.ndarray, pd.Series | np.ndarray]

def tune_model_recall_constrained(
    model_cls: Type[ClassifierMixin],
    param_space: Dict[str, Any],
    train_data: DataType,
    val_data: DataType,
    primary_target_class: int,        # Class to MAXIMIZE recall for (e.g., 1)
    constraint_class: int,            # Class to apply recall CONSTRAINT on (e.g., 0)
    constraint_recall_level: float,   # Minimum recall for constraint_class (e.g., 0.98)
    max_evals: int = 50,
    mlflow_experiment_name: str = "HP Tuning Constrained Recall",
    mlflow_run_name: str = "Constrained Recall Opt Run",
    random_state: int | None = 42
) -> Dict[str, Any]:
    """
    Performs hyperparameter tuning optimizing recall for 'primary_target_class',
    subject to a minimum recall constraint on 'constraint_class'.

    Args:
        model_cls: Classifier class.
        param_space: Hyperopt search space.
        train_data: (X_train, y_train).
        val_data: (X_val, y_val).
        primary_target_class: Class index (0 or 1) whose recall we want to maximize.
        constraint_class: Class index (0 or 1) which must meet a recall threshold.
        constraint_recall_level: The minimum recall required for the constraint_class.
        max_evals: Max hyperopt trials.
        mlflow_experiment_name: MLflow experiment name.
        mlflow_run_name: MLflow parent run name.
        random_state: Random seed.

    Returns:
        Dictionary of the best hyperparameters found.
    """
    X_train, y_train = train_data
    X_val, y_val = val_data

    if primary_target_class == constraint_class:
        raise ValueError("Primary target class and constraint class cannot be the same.")

    mlflow.set_experiment(mlflow_experiment_name)

    # Define the objective function for Hyperopt
    def objective(params: Dict[str, Any]) -> Dict[str, Any]:
        # --- Cast integer params if needed (e.g., for XGBoost) ---
        if 'n_estimators' in params: params['n_estimators'] = int(params['n_estimators'])
        if 'max_depth' in params: params['max_depth'] = int(params['max_depth'])
        if 'min_child_weight' in params: params['min_child_weight'] = int(params['min_child_weight'])
        # Add other int castings as necessary based on your param_space and model_cls

        with mlflow.start_run(nested=True) as trial_run:
            start_time = time.time()
            mlflow.log_params(params)
            mlflow.log_param("primary_target_class", primary_target_class)
            mlflow.log_param("constraint_class", constraint_class)
            mlflow.log_param("constraint_recall_level", constraint_recall_level)
            mlflow.log_param("model_class", model_cls.__name__)

            metric_recall_primary = 0.0 # Metric we want to maximize
            metric_recall_constraint = 0.0 # Achieved recall for constraint class
            threshold_used = None
            loss = 1.0 # Default loss (worst case if constraint not met)
            status = STATUS_FAIL # Default status

            try:
                # Add random_state if applicable
                if 'random_state' in model_cls().get_params().keys() and random_state is not None:
                     if 'random_state' not in params:
                         params['random_state'] = random_state

                # Instantiate and train
                model = model_cls(**params)
                model.fit(X_train, y_train)

                # Predict probabilities for the *positive* class (class 1) on validation set
                if not hasattr(model, "predict_proba"):
                     raise TypeError(f"Model {model_cls.__name__} does not have predict_proba method.")
                y_pred_proba_val = model.predict_proba(X_val)[:, 1] # Prob of class 1

                # Find threshold meeting constraint on constraint_class
                threshold_used, metric_recall_constraint = find_threshold_binary_search(
                    y_true=y_val,
                    y_pred_proba=y_pred_proba_val,
                    target_recall=constraint_recall_level,
                    target_class=constraint_class
                )

                # If a valid threshold was found...
                if threshold_used is not None:
                    # Apply the threshold to get final predictions
                    y_pred_val_adjusted = (y_pred_proba_val >= threshold_used).astype(int)

                    # Calculate recall for the primary target class
                    metric_recall_primary = recall_score(
                        y_val,
                        y_pred_val_adjusted,
                        pos_label=primary_target_class,
                        average='binary',
                        zero_division=0
                    )
                    loss = 1.0 - metric_recall_primary # Minimize (1 - Recall)
                    status = STATUS_OK
                    mlflow.set_tag("constraint_met", "True")
                else:
                    # Constraint not met, this trial is considered suboptimal
                    loss = 1.0 # Assign worst loss
                    metric_recall_primary = 0.0 # No primary recall achieved under constraint
                    metric_recall_constraint = 0.0 # Report 0 constraint recall if threshold is None
                    status = STATUS_OK # Mark as OK but with worst loss, or use STATUS_FAIL
                    mlflow.set_tag("constraint_met", "False")


            except Exception as e:
                loss = 1.0 # Worst loss on error
                status = STATUS_FAIL
                mlflow.set_tag("status", "failed")
                mlflow.log_param("error_message", str(e))
                print(f"Trial FAILED with parameters: {params}\nError: {e}")
                print("-" * 30)
                # Ensure metrics are logged even on failure
                metric_recall_primary = 0.0
                metric_recall_constraint = 0.0
                threshold_used = None


            # Log metrics for this trial
            end_time = time.time()
            duration = end_time - start_time
            mlflow.log_metric(f"recall_class_{primary_target_class}", metric_recall_primary)
            mlflow.log_metric(f"recall_class_{constraint_class}", metric_recall_constraint if metric_recall_constraint is not None else 0.0) # Handle None case
            mlflow.log_metric("loss", loss)
            mlflow.log_metric("training_duration_seconds", duration)
            if threshold_used is not None:
                mlflow.log_metric("threshold_used", threshold_used)

            print(f"Trial Params: {params}")
            print(f"Constraint Met: {threshold_used is not None}")
            if threshold_used is not None:
                print(f"  Threshold: {threshold_used:.4f}")
                print(f"  Recall Class {constraint_class} (Constraint >= {constraint_recall_level:.2f}): {metric_recall_constraint:.4f}")
                print(f"  Recall Class {primary_target_class} (Maximized): {metric_recall_primary:.4f}")
            print(f"Loss (1 - Recall_{primary_target_class}): {loss:.4f}, Duration: {duration:.2f}s")
            print("-" * 30)

            return {
                'loss': loss,
                'status': status,
                'eval_time': duration,
                'params': params,
                # Store metrics achieved in this trial's result dict
                f'recall_class_{primary_target_class}': metric_recall_primary,
                f'recall_class_{constraint_class}': metric_recall_constraint if metric_recall_constraint is not None else 0.0,
                'threshold_used': threshold_used if threshold_used is not None else -1.0 # Use -1 or similar for non-None logging
            }

    # --- Hyperopt Execution ---
    trials = Trials()
    rstate = np.random.default_rng(random_state) if random_state is not None else None

    with mlflow.start_run(run_name=mlflow_run_name) as parent_run:
        print(f"Starting Hyperopt optimization for {model_cls.__name__}...")
        print(f"Maximizing recall of Class {primary_target_class}")
        print(f"Subject to Recall of Class {constraint_class} >= {constraint_recall_level:.4f}")
        print(f"Max evaluations: {max_evals}")
        print(f"Search Space: {param_space}")
        print("-" * 30)

        mlflow.log_param("model_class", model_cls.__name__)
        mlflow.log_param("primary_target_class", primary_target_class)
        mlflow.log_param("constraint_class", constraint_class)
        mlflow.log_param("constraint_recall_level", constraint_recall_level)
        mlflow.log_param("max_evals", max_evals)
        # mlflow.log_param("param_space", str(param_space)) # Careful with large spaces

        best_result = fmin(
            fn=objective,
            space=param_space,
            algo=tpe.suggest,
            max_evals=max_evals,
            trials=trials,
            rstate=rstate
        )

        # --- Post-tuning ---
        best_params_raw = best_result
        best_params = space_eval(param_space, best_params_raw)

        # Find the best trial object based on lowest loss where status is OK
        valid_trials = [t for t in trials.results if t['status'] == STATUS_OK and t['loss'] != 1.0] # Exclude constraint-not-met trials
        if not valid_trials:
             best_trial = min(trials.results, key=lambda x: x['loss'] if x['status'] == STATUS_OK else float('inf')) # Fallback if ALL failed constraint
             print("\nWARNING: No trial successfully met the recall constraint. Reporting best overall attempt.")
        else:
            best_trial = min(valid_trials, key=lambda x: x['loss'])


        print("\n" + "=" * 30)
        print("Hyperparameter Tuning Complete!")
        print(f"Best Parameters Found (raw): {best_params_raw}")
        print(f"Best Parameters Found (evaluated): {best_params}")

        if best_trial['status'] == STATUS_OK:
            best_recall_primary = best_trial[f'recall_class_{primary_target_class}']
            best_recall_constraint = best_trial[f'recall_class_{constraint_class}']
            best_threshold = best_trial['threshold_used']
            best_loss = best_trial['loss']

            print(f"\nBest Trial Results:")
            print(f"  Loss (1 - Recall Class {primary_target_class}): {best_loss:.4f}")
            print(f"  Recall Class {primary_target_class} (Maximized): {best_recall_primary:.4f}")
            print(f"  Recall Class {constraint_class} (Constraint >= {constraint_recall_level:.2f}): {best_recall_constraint:.4f}")
            print(f"  Threshold Used: {best_threshold if best_threshold != -1.0 else 'N/A (Constraint Failed)'}") # Handle logged -1

            # MLflow: Log best results to the parent run
            mlflow.log_params(best_params) # Log the actual best param values
            mlflow.log_metric(f"best_val_recall_class_{primary_target_class}", best_recall_primary)
            mlflow.log_metric(f"best_val_recall_class_{constraint_class}", best_recall_constraint)
            if best_threshold != -1.0: # Log threshold if valid
                mlflow.log_metric("best_threshold_used", best_threshold)
            mlflow.log_metric("best_val_loss", best_loss)
            mlflow.set_tag("best_params", str(best_params))
            mlflow.set_tag("constraint_status_for_best", "Met" if best_threshold != -1.0 else "Not Met")
        else:
            print("\nNo successful trial completed or constraint met.")
            mlflow.set_tag("status", "tuning_failed_or_constraint_unmet")

        print("=" * 30)

    return best_params

# %%
from xgboost import XGBClassifier

model_to_tune = XGBClassifier

xgb_param_space = {
    # --- Tree Booster Parameters ---

    # n_estimators: Number of gradient boosted trees. Equivalent to number of boosting rounds.
    # Typically more estimators require lower learning rates.
    # Using quniform and casting to int in the objective function is common.
    'n_estimators': hp.quniform('n_estimators', 100, 1000, 50), # From 100 to 1000, steps of 50

    # learning_rate (eta): Step size shrinkage used in update to prevents overfitting.
    # Typical final values are between 0.01 and 0.3. Loguniform is good here.
    'learning_rate': hp.loguniform('learning_rate', np.log(0.005), np.log(0.3)), # Range 0.005 to 0.3 (log scale)

    # max_depth: Maximum depth of a tree. Deeper trees capture more complexity but can overfit.
    # Typical values between 3 and 10.
    'max_depth': hp.quniform('max_depth', 3, 7, 1), # Integer values from 3 to 7

    # min_child_weight: Minimum sum of instance weight (hessian) needed in a child.
    # Used to control over-fitting. Larger values prevent learning highly specific relations.
    'min_child_weight': hp.quniform('min_child_weight', 1, 10, 1), # Integer values from 1 to 10

    # gamma (min_split_loss): Minimum loss reduction required to make a further partition on a leaf node.
    # Larger gamma leads to more conservative algorithm. Ranges from 0 to infinity.
    'gamma': hp.uniform('gamma', 0.0, 1.0), # Range 0.0 to 1.0

    # subsample: Fraction of samples to be used for fitting the individual base learners.
    # Lower values make the algorithm more conservative and prevent overfitting but too small values might lead to under-fitting.
    # Typical values between 0.5 and 1.0.
    'subsample': hp.uniform('subsample', 0.5, 1.0), # Range 0.5 to 1.0 (exclusive of 1.0?) -> check docs. XGBoost usually allows 1.0

    # colsample_bytree: Fraction of features to consider when building each tree.
    # Typical values between 0.5 and 1.0.
    'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1.0),

    # colsample_bylevel: Fraction of features to consider for each level. (Less common to tune than colsample_bytree)
    'colsample_bylevel': hp.uniform('colsample_bylevel', 0.5, 1.0),

    # colsample_bynode: Fraction of features to consider for each split. (Less common to tune)
    'colsample_bynode': hp.uniform('colsample_bynode', 0.5, 1.0),

    # --- Regularization Parameters ---

    # reg_alpha (L1 regularization): L1 regularization term on weights. Encourages sparsity.
    'reg_alpha': hp.loguniform('reg_alpha', np.log(0.001), np.log(1.0)), # Range 0.001 to 1.0 (log scale)

    # reg_lambda (L2 regularization): L2 regularization term on weights. Encourages smaller weights.
    'reg_lambda': hp.uniform('reg_lambda', 0.1, 10.0), # Range 0.1 to 10.0

    # --- Imbalance Parameter ---

    # scale_pos_weight: Control the balance of positive and negative weights.
    # Useful for unbalanced classes. A typical value to consider: sum(negative instances) / sum(positive instances)
    # Since you optimize for recall of class 1, this is highly relevant if class 1 is the minority class.
    # Adjust the range based on your imbalance ratio. If class 1 is ~10% of data, ratio is ~9.
    'scale_pos_weight': hp.uniform('scale_pos_weight', 1, 20), # Example: search range from 1 (no reweighting) up to 20. ADJUST THIS.

    # --- Fixed Parameters (Usually set outside search space) ---
    # 'objective': 'binary:logistic' or 'multi:softprob' / 'multi:softmax' - Set based on your problem
    # 'eval_metric': Metric used for early stopping (e.g., 'logloss', 'auc', 'error', 'aucpr') - Often set based on goal
    # 'use_label_encoder': Deprecated, set to False if using recent xgboost/sklearn
    # 'booster': 'gbtree', 'gblinear' or 'dart'. Usually 'gbtree'.
    'random_state': 0,
    'tree_method': 'hist', # Use 'hist' for faster training on large datasets
    'device': 'cuda'
}

# %%
train_df
# Out:
#                                               customer_ID      D_39       B_1  \
# 0       0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  0.009119  0.009382
# 1       00001b22f846c82c51f6e3958ccd81970162bae8b007e8...  0.009704  0.004284
# 2       000084e5023181993c2e1b665ac88dbb1ce9ef621ec537...  0.009776  0.007853
# 3       000098081fde4fd64bc4d503a5d6f86a0aedc425c96f52...  0.000467  0.009413
# 4       0000f99513770170a1aba690daeeb8a96da4a39f11fc27...  0.531173  0.979303
# ...                                                   ...       ...       ...
# 289110  fffe3ec7cdbc1caac845c884b389ed347bfc1da9d09731...  0.917061  0.140985
# 289111  fffef3305f19a11fb6c15f4ebe9be1bd664540e57c0a6a...  0.361938  0.527205
# 289112  ffff39cc22a375d07369980d02d617883dd28ad81a6aa3...  0.030825  0.069242
# 289113  ffff518bb2075e4816ee3fe9f3b152c57fc0e6f01bf7fd...  0.033670  0.292360
# 289114  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  0.002474  0.000077
#
#              R_1       B_4       B_5       R_2      D_47       B_7      D_51  \
# 0       0.006104  0.070793  0.231717  0.008309  0.539715  0.058425  0.673522
# 1       0.006450  0.031044  0.001557  0.001687  0.339125  0.026981  0.342118
# 2       0.006885  0.004432  0.012747  0.008217  1.053603  0.006804  0.003867
# 3       0.007775  0.002541  0.006761  0.000599  0.016223  0.010545  0.005974
# 4       0.008500  1.105429  0.025943  0.003394  0.125423  0.998107  0.000275
# ...          ...       ...       ...       ...       ...       ...       ...
# 289110  1.257408  0.361112  0.014141  1.001527  0.174051  0.301254  0.000635
# 289111  0.004604  0.269388  0.020230  0.003710  0.263061  0.441786  0.007279
# 289112  0.008615  0.065738  0.007201  0.001451  0.405907  0.037397  0.000310
# 289113  0.006953  0.248441  0.018681  0.009918  0.774590  0.272163  0.342166
# 289114  0.000809  0.018335  0.006617  0.001016  0.531610  0.028185  0.008057
#
#         ...  S_5_Signal distance  B_14_Mean diff  B_11_Mean diff  \
# 0       ...            12.002586       -0.000679        0.000624
# 1       ...            12.000076        0.000399        0.000285
# 2       ...            12.002037        0.000065       -0.000788
# 3       ...            12.000053       -0.000506       -0.002254
# 4       ...            12.001062       -0.001064        0.002243
# ...     ...                  ...             ...             ...
# 289110  ...            12.002731        0.000332        0.001340
# 289111  ...            12.001008       -0.001295       -0.011948
# 289112  ...            12.000117       -0.000405       -0.001764
# 289113  ...            12.000050       -0.002843       -0.012070
# 289114  ...            12.007563       -0.005131       -0.007703
#
#         S_8_Area under the curve  B_11_Area under the curve  S_8_Centroid  \
# 0                       0.096573                   0.000875      0.051362
# 1                       0.000758                   0.000575      0.066659
# 2                       0.030051                   0.001411      0.053169
# 3                       0.026627                   0.005694      0.052700
# 4                       0.018268                   0.113519      0.105902
# ...                          ...                        ...           ...
# 289110                  0.005416                   0.013595      0.015254
# 289111                  0.019677                   0.066953      0.028782
# 289112                  0.022082                   0.009564      0.089815
# 289113                  0.006552                   0.037837      0.010031
# 289114                  0.060235                   0.002879      0.050992
#
#         B_1_Area under the curve  B_1_Mean diff  S_26_Area under the curve  \
# 0                       0.001470       0.000055                   0.001620
# 1                       0.000541       0.000234                   0.000715
# 2                       0.003310      -0.002275                   0.000515
# 3                       0.008939      -0.002907                   0.000445
# 4                       0.112342       0.002037                   0.000684
# ...                          ...            ...                        ...
# 289110                  0.018414       0.000258                   0.000700
# 289111                  0.069013      -0.010969                   0.000420
# 289112                  0.012372      -0.002424                   0.012091
# 289113                  0.044265      -0.011587                   0.000623
# 289114                  0.004337      -0.009950                   0.000387
#
#         S_5_Area under the curve
# 0                       0.003494
# 1                       0.000725
# 2                       0.002074
# 3                       0.001086
# 4                       0.002241
# ...                          ...
# 289110                  0.007798
# 289111                  0.002695
# 289112                  0.000623
# 289113                  0.000974
# 289114                  0.006222
#
# [289115 rows x 426 columns]

# %%
# --- Tuning Configuration ---
PRIMARY_CLASS = 1 # Maximize recall for the minority class 1
CONSTRAINT_CLASS = 0 # Ensure recall for majority class 0 is high
CONSTRAINT_RECALL = 0.98 # Target recall for class 0
MAX_EVALUATIONS = 100 # Increase for better results

best_hyperparameters = tune_model_recall_constrained(
    model_cls=model_to_tune,
    param_space=xgb_param_space,
    train_data=(train_df.drop(columns=['customer_ID']), y_train['target'].values),
    val_data=(val_df.drop(columns=['customer_ID']), y_val['target'].values),
    primary_target_class=PRIMARY_CLASS,
    constraint_class=CONSTRAINT_CLASS,
    constraint_recall_level=CONSTRAINT_RECALL,
    max_evals=MAX_EVALUATIONS,
    mlflow_experiment_name="HP Tuning",
    mlflow_run_name=f"Tuning {model_to_tune.__name__}",
    random_state=42
)
# Out:
# 2025/04/17 12:19:52 INFO mlflow.tracking.fluent: Experiment with name 'HP Tuning' does not exist. Creating a new experiment.
# Starting Hyperopt optimization for XGBClassifier...
# Maximizing recall of Class 1
# Subject to Recall of Class 0 >= 0.9800
# Max evaluations: 100
# Search Space: {'n_estimators': <hyperopt.pyll.base.Apply object at 0x00000173E320CCD0>, 'learning_rate': <hyperopt.pyll.base.Apply object at 0x00000173FB084580>, 'max_depth': <hyperopt.pyll.base.Apply object at 0x00000173FB084070>, 'min_child_weight': <hyperopt.pyll.base.Apply object at 0x00000173FB084700>, 'gamma': <hyperopt.pyll.base.Apply object at 0x00000173FB084970>, 'subsample': <hyperopt.pyll.base.Apply object at 0x00000173FB084A90>, 'colsample_bytree': <hyperopt.pyll.base.Apply object at 0x00000173FB084BB0>, 'colsample_bylevel': <hyperopt.pyll.base.Apply object at 0x00000173FB084CD0>, 'colsample_bynode': <hyperopt.pyll.base.Apply object at 0x00000173FB084DF0>, 'reg_alpha': <hyperopt.pyll.base.Apply object at 0x00000173FB084F10>, 'reg_lambda': <hyperopt.pyll.base.Apply object at 0x00000173FB085030>, 'scale_pos_weight': <hyperopt.pyll.base.Apply object at 0x00000173FB085150>, 'random_state': 0, 'tree_method': 'hist', 'device': 'cuda'}
# ------------------------------
#   0%|          | 0/100 [00:00<?, ?trial/s, best loss=?]
# c:\Users\vaseekaranv\AppData\Local\anaconda3\envs\nibm_dl\lib\site-packages\xgboost\core.py:158: UserWarning: [12:20:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9736104
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.5304174185556783, 'colsample_bynode': 0.542962261035576, 'colsample_bytree': 0.9949418999050212, 'device': 'cuda', 'gamma': 0.48418490583849105, 'learning_rate': 0.018840364243506717, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 800, 'random_state': 0, 'reg_alpha': 0.09020429139714789, 'reg_lambda': 8.850873592178893, 'scale_pos_weight': 12.782260955856179, 'subsample': 0.9068277038201439, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9736
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5537
# Loss (1 - Recall_1): 0.4463, Duration: 25.25s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9570844
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.9357615217358524, 'colsample_bynode': 0.6751198707743986, 'colsample_bytree': 0.6043143849848778, 'device': 'cuda', 'gamma': 0.34187263717236394, 'learning_rate': 0.005113621243976496, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 600, 'random_state': 0, 'reg_alpha': 0.0015128942324737992, 'reg_lambda': 8.623211770943003, 'scale_pos_weight': 12.556734081251594, 'subsample': 0.6502106773952542, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9571
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5228
# Loss (1 - Recall_1): 0.4772, Duration: 28.41s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.8803210
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.8200333965790645, 'colsample_bynode': 0.6419407898437077, 'colsample_bytree': 0.6950353283872053, 'device': 'cuda', 'gamma': 0.6659371988120061, 'learning_rate': 0.04302614189758269, 'max_depth': 7, 'min_child_weight': 8, 'n_estimators': 600, 'random_state': 0, 'reg_alpha': 0.0029616866087217274, 'reg_lambda': 6.21484242760273, 'scale_pos_weight': 2.3995594835599583, 'subsample': 0.5734813936425138, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.8803
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5612
# Loss (1 - Recall_1): 0.4388, Duration: 23.77s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9319654
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.5811708741931823, 'colsample_bynode': 0.9912890682107216, 'colsample_bytree': 0.5911413880562895, 'device': 'cuda', 'gamma': 0.2524230054951294, 'learning_rate': 0.05452271238124363, 'max_depth': 4, 'min_child_weight': 6, 'n_estimators': 150, 'random_state': 0, 'reg_alpha': 0.12983149225948815, 'reg_lambda': 5.965288791925494, 'scale_pos_weight': 5.032125222873369, 'subsample': 0.7018888351309895, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9320
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5394
# Loss (1 - Recall_1): 0.4606, Duration: 6.37s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9022604
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.9040379001419955, 'colsample_bynode': 0.8051146909686047, 'colsample_bytree': 0.5820072981400288, 'device': 'cuda', 'gamma': 0.678318218947999, 'learning_rate': 0.1130217749669301, 'max_depth': 5, 'min_child_weight': 5, 'n_estimators': 400, 'random_state': 0, 'reg_alpha': 0.010923348581454497, 'reg_lambda': 2.944827566547015, 'scale_pos_weight': 2.8362482678631737, 'subsample': 0.7514518773307409, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9023
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5509
# Loss (1 - Recall_1): 0.4491, Duration: 11.54s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9279792
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.8452772055859286, 'colsample_bynode': 0.8046347435632573, 'colsample_bytree': 0.536217493042938, 'device': 'cuda', 'gamma': 0.8573161105400177, 'learning_rate': 0.16235635364410347, 'max_depth': 5, 'min_child_weight': 6, 'n_estimators': 900, 'random_state': 0, 'reg_alpha': 0.14772152190499194, 'reg_lambda': 4.475239643689288, 'scale_pos_weight': 4.059458063732199, 'subsample': 0.8773636801323945, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9280
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5446
# Loss (1 - Recall_1): 0.4554, Duration: 20.39s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9760197
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.8484717857453363, 'colsample_bynode': 0.52790234553208, 'colsample_bytree': 0.8095112806591597, 'device': 'cuda', 'gamma': 0.4315908013703734, 'learning_rate': 0.008626759759092897, 'max_depth': 4, 'min_child_weight': 10, 'n_estimators': 550, 'random_state': 0, 'reg_alpha': 0.40557179870278204, 'reg_lambda': 0.9092947253263426, 'scale_pos_weight': 19.942756988102005, 'subsample': 0.8495392973707541, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9760
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5173
# Loss (1 - Recall_1): 0.4827, Duration: 13.42s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9740481
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.506587413206087, 'colsample_bynode': 0.5479293595427644, 'colsample_bytree': 0.8605487051813354, 'device': 'cuda', 'gamma': 0.9128315228964865, 'learning_rate': 0.019626646998269194, 'max_depth': 6, 'min_child_weight': 8, 'n_estimators': 250, 'random_state': 0, 'reg_alpha': 0.010255083898098764, 'reg_lambda': 7.505554152307968, 'scale_pos_weight': 16.77170301507713, 'subsample': 0.5321434316547746, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9740
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5386
# Loss (1 - Recall_1): 0.4614, Duration: 10.71s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9808762
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.7858664856925227, 'colsample_bynode': 0.5567982554608459, 'colsample_bytree': 0.8805920442820685, 'device': 'cuda', 'gamma': 0.3792874013620091, 'learning_rate': 0.1596668795216907, 'max_depth': 4, 'min_child_weight': 4, 'n_estimators': 1000, 'random_state': 0, 'reg_alpha': 0.05252703759208615, 'reg_lambda': 0.6353709569974215, 'scale_pos_weight': 15.65623553432091, 'subsample': 0.8616492018371803, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9809
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5468
# Loss (1 - Recall_1): 0.4532, Duration: 19.75s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9570941
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.5316989243876096, 'colsample_bynode': 0.839834022606311, 'colsample_bytree': 0.8086929748705218, 'device': 'cuda', 'gamma': 0.5044490300771175, 'learning_rate': 0.007140509080812348, 'max_depth': 4, 'min_child_weight': 7, 'n_estimators': 700, 'random_state': 0, 'reg_alpha': 0.12953948636839732, 'reg_lambda': 4.406479741142982, 'scale_pos_weight': 10.130586205513582, 'subsample': 0.6625161963677373, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9571
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5240
# Loss (1 - Recall_1): 0.4760, Duration: 16.96s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.8487570
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.7688920106904573, 'colsample_bynode': 0.6938188360051636, 'colsample_bytree': 0.8028247433087468, 'device': 'cuda', 'gamma': 0.5089129645696884, 'learning_rate': 0.020625416768734663, 'max_depth': 6, 'min_child_weight': 6, 'n_estimators': 950, 'random_state': 0, 'reg_alpha': 0.7317139587707565, 'reg_lambda': 2.7564150617343217, 'scale_pos_weight': 1.7839467900473416, 'subsample': 0.51735171792841, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.8488
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5575
# Loss (1 - Recall_1): 0.4425, Duration: 35.50s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9768502
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.5056003381524676, 'colsample_bynode': 0.6094388838143366, 'colsample_bytree': 0.7354148015000581, 'device': 'cuda', 'gamma': 0.20313579508936952, 'learning_rate': 0.21574168869967641, 'max_depth': 5, 'min_child_weight': 10, 'n_estimators': 350, 'random_state': 0, 'reg_alpha': 0.008383276620790615, 'reg_lambda': 1.137823108760039, 'scale_pos_weight': 12.554895313291128, 'subsample': 0.8905439168319457, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9769
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5434
# Loss (1 - Recall_1): 0.4566, Duration: 17.41s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9759066
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.6989985321828889, 'colsample_bynode': 0.740161996231615, 'colsample_bytree': 0.7808177926672928, 'device': 'cuda', 'gamma': 0.612305146671109, 'learning_rate': 0.011211487951859746, 'max_depth': 5, 'min_child_weight': 6, 'n_estimators': 850, 'random_state': 0, 'reg_alpha': 0.004473104328583632, 'reg_lambda': 6.1301310759743615, 'scale_pos_weight': 14.870752406879024, 'subsample': 0.6415804690150524, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9759
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5466
# Loss (1 - Recall_1): 0.4534, Duration: 35.35s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9681449
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.7221491247969757, 'colsample_bynode': 0.5353077945087408, 'colsample_bytree': 0.7824582083523829, 'device': 'cuda', 'gamma': 0.3051691139539223, 'learning_rate': 0.08224119319763853, 'max_depth': 5, 'min_child_weight': 3, 'n_estimators': 800, 'random_state': 0, 'reg_alpha': 0.44289362804791116, 'reg_lambda': 0.9796332958517908, 'scale_pos_weight': 9.875822750872718, 'subsample': 0.5337114618970547, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9681
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5559
# Loss (1 - Recall_1): 0.4441, Duration: 30.80s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9763212
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.5062867334868206, 'colsample_bynode': 0.686825943012109, 'colsample_bytree': 0.9075384840569793, 'device': 'cuda', 'gamma': 0.442579530761786, 'learning_rate': 0.027057951125414516, 'max_depth': 5, 'min_child_weight': 3, 'n_estimators': 200, 'random_state': 0, 'reg_alpha': 0.8353026129385788, 'reg_lambda': 0.2692572304826705, 'scale_pos_weight': 18.208901077049656, 'subsample': 0.6162303187347985, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9763
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5359
# Loss (1 - Recall_1): 0.4641, Duration: 12.54s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9838319
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.5294638952804434, 'colsample_bynode': 0.9443867210816617, 'colsample_bytree': 0.8252259857772298, 'device': 'cuda', 'gamma': 0.15821390200459173, 'learning_rate': 0.22751487368528722, 'max_depth': 5, 'min_child_weight': 2, 'n_estimators': 850, 'random_state': 0, 'reg_alpha': 0.01010602302007944, 'reg_lambda': 2.122414094900606, 'scale_pos_weight': 19.76700702724067, 'subsample': 0.9376238045745737, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9838
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5352
# Loss (1 - Recall_1): 0.4648, Duration: 34.43s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9751749
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.9055490565398088, 'colsample_bynode': 0.9128770407458957, 'colsample_bytree': 0.571063725439524, 'device': 'cuda', 'gamma': 0.21351474883946298, 'learning_rate': 0.018928312717325976, 'max_depth': 3, 'min_child_weight': 4, 'n_estimators': 400, 'random_state': 0, 'reg_alpha': 0.022640034668132605, 'reg_lambda': 8.188248165712313, 'scale_pos_weight': 16.46758588149986, 'subsample': 0.9411338024873159, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9752
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5263
# Loss (1 - Recall_1): 0.4737, Duration: 14.70s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.8005190
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.9139643954671376, 'colsample_bynode': 0.878335154893285, 'colsample_bytree': 0.9492129541270184, 'device': 'cuda', 'gamma': 0.29946006769611155, 'learning_rate': 0.0068818058410250295, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 250, 'random_state': 0, 'reg_alpha': 0.850307309630457, 'reg_lambda': 3.571764603405996, 'scale_pos_weight': 2.9585592565946697, 'subsample': 0.6624745156815548, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.8005
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.4680
# Loss (1 - Recall_1): 0.5320, Duration: 12.93s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9846113
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.9096962827067488, 'colsample_bynode': 0.7293924984245805, 'colsample_bytree': 0.8063565296900386, 'device': 'cuda', 'gamma': 0.9849772091031403, 'learning_rate': 0.21503776275189757, 'max_depth': 6, 'min_child_weight': 7, 'n_estimators': 400, 'random_state': 0, 'reg_alpha': 0.01784382948784887, 'reg_lambda': 1.3679612696710812, 'scale_pos_weight': 17.14724360140753, 'subsample': 0.6226067744404331, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9846
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5167
# Loss (1 - Recall_1): 0.4833, Duration: 22.20s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9713098
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.8881381933442813, 'colsample_bynode': 0.551729538795357, 'colsample_bytree': 0.7328396376485163, 'device': 'cuda', 'gamma': 0.1970888480775166, 'learning_rate': 0.014923133969973745, 'max_depth': 6, 'min_child_weight': 6, 'n_estimators': 350, 'random_state': 0, 'reg_alpha': 0.004892235875204629, 'reg_lambda': 9.762398987615278, 'scale_pos_weight': 14.547845908774125, 'subsample': 0.7236617974934909, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9713
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5390
# Loss (1 - Recall_1): 0.4610, Duration: 23.90s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9499578
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.9909164557973996, 'colsample_bynode': 0.6280438577172883, 'colsample_bytree': 0.6635614685839953, 'device': 'cuda', 'gamma': 0.753182040698997, 'learning_rate': 0.04112636959427656, 'max_depth': 7, 'min_child_weight': 9, 'n_estimators': 650, 'random_state': 0, 'reg_alpha': 0.0018844096477401303, 'reg_lambda': 6.123625372835702, 'scale_pos_weight': 6.349520034424425, 'subsample': 0.5031298495774765, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9500
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5500
# Loss (1 - Recall_1): 0.4500, Duration: 52.45s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.7915754
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.6351653281967298, 'colsample_bynode': 0.6395225520704871, 'colsample_bytree': 0.688131709586635, 'device': 'cuda', 'gamma': 0.025879927244853218, 'learning_rate': 0.032307782065094444, 'max_depth': 7, 'min_child_weight': 8, 'n_estimators': 1000, 'random_state': 0, 'reg_alpha': 0.00301357344147134, 'reg_lambda': 7.254618325985421, 'scale_pos_weight': 1.1525017679777356, 'subsample': 0.5827559358848895, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.7916
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5617
# Loss (1 - Recall_1): 0.4383, Duration: 67.76s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9567198
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.6557380822197646, 'colsample_bynode': 0.6080541996599654, 'colsample_bytree': 0.673733608168075, 'device': 'cuda', 'gamma': 0.00011996769430783205, 'learning_rate': 0.06052898104955657, 'max_depth': 7, 'min_child_weight': 9, 'n_estimators': 700, 'random_state': 0, 'reg_alpha': 0.0010332464564855642, 'reg_lambda': 6.821033114855129, 'scale_pos_weight': 7.8563511455171575, 'subsample': 0.5804948767671563, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9567
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5517
# Loss (1 - Recall_1): 0.4483, Duration: 49.86s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9585801
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.6300856634464322, 'colsample_bynode': 0.6526074505852351, 'colsample_bytree': 0.6697112212831566, 'device': 'cuda', 'gamma': 0.7604562298503592, 'learning_rate': 0.032619104871859005, 'max_depth': 7, 'min_child_weight': 8, 'n_estimators': 550, 'random_state': 0, 'reg_alpha': 0.002445992275837791, 'reg_lambda': 5.492890263537331, 'scale_pos_weight': 7.861367769377944, 'subsample': 0.7956767217032639, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9586
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5501
# Loss (1 - Recall_1): 0.4499, Duration: 23.37s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.8236824
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.8086051246545463, 'colsample_bynode': 0.5891736715269076, 'colsample_bytree': 0.697986781099706, 'device': 'cuda', 'gamma': 0.6027056750444493, 'learning_rate': 0.05459889330685934, 'max_depth': 7, 'min_child_weight': 9, 'n_estimators': 1000, 'random_state': 0, 'reg_alpha': 0.003440339810830874, 'reg_lambda': 9.734666197932619, 'scale_pos_weight': 1.3701206944224031, 'subsample': 0.5797963063353142, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.8237
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5554
# Loss (1 - Recall_1): 0.4446, Duration: 36.46s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.8165901
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.6772958491795934, 'colsample_bynode': 0.5015922398866216, 'colsample_bytree': 0.6262874049555927, 'device': 'cuda', 'gamma': 0.011999548539464867, 'learning_rate': 0.08684285571489475, 'max_depth': 7, 'min_child_weight': 8, 'n_estimators': 700, 'random_state': 0, 'reg_alpha': 0.005968070601147094, 'reg_lambda': 7.00512350228084, 'scale_pos_weight': 1.1944596600925406, 'subsample': 0.5728875031671876, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.8166
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5469
# Loss (1 - Recall_1): 0.4531, Duration: 28.58s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9425335
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.6034950138586829, 'colsample_bynode': 0.7776595948188642, 'colsample_bytree': 0.5296524592314809, 'device': 'cuda', 'gamma': 0.07848269117555573, 'learning_rate': 0.040189895522691706, 'max_depth': 6, 'min_child_weight': 7, 'n_estimators': 500, 'random_state': 0, 'reg_alpha': 0.0011737137554988044, 'reg_lambda': 7.726226292224142, 'scale_pos_weight': 5.574164569138075, 'subsample': 0.9990345583613596, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9425
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5585
# Loss (1 - Recall_1): 0.4415, Duration: 27.20s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9020870
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.7374688963706748, 'colsample_bynode': 0.6530939995253102, 'colsample_bytree': 0.634552954455796, 'device': 'cuda', 'gamma': 0.5964684982831783, 'learning_rate': 0.03052565809663588, 'max_depth': 7, 'min_child_weight': 10, 'n_estimators': 750, 'random_state': 0, 'reg_alpha': 0.003043317738545787, 'reg_lambda': 9.157073173609701, 'scale_pos_weight': 3.1428643512026886, 'subsample': 0.7801374674314345, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9021
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5606
# Loss (1 - Recall_1): 0.4394, Duration: 50.25s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9487102
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.566601308403576, 'colsample_bynode': 0.7150062639976358, 'colsample_bytree': 0.7089091893525071, 'device': 'cuda', 'gamma': 0.7815241873453262, 'learning_rate': 0.011814529973887494, 'max_depth': 6, 'min_child_weight': 8, 'n_estimators': 500, 'random_state': 0, 'reg_alpha': 0.045932579930858544, 'reg_lambda': 4.512176097026389, 'scale_pos_weight': 7.329873123192691, 'subsample': 0.6951252599119454, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9487
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5489
# Loss (1 - Recall_1): 0.4511, Duration: 28.79s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.6601534
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.8362666370355273, 'colsample_bynode': 0.5841884160886907, 'colsample_bytree': 0.5017688007651993, 'device': 'cuda', 'gamma': 0.6912165782863158, 'learning_rate': 0.025564643916094983, 'max_depth': 3, 'min_child_weight': 9, 'n_estimators': 100, 'random_state': 0, 'reg_alpha': 0.01983624932064306, 'reg_lambda': 6.6614718688259105, 'scale_pos_weight': 1.0174758108077337, 'subsample': 0.5636901600764367, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.6602
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.4824
# Loss (1 - Recall_1): 0.5176, Duration: 7.66s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9599779
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.9755588265430747, 'colsample_bynode': 0.7723767518416151, 'colsample_bytree': 0.6298376801089061, 'device': 'cuda', 'gamma': 0.8633297121358477, 'learning_rate': 0.07867703498897811, 'max_depth': 7, 'min_child_weight': 7, 'n_estimators': 950, 'random_state': 0, 'reg_alpha': 0.0018271383033652278, 'reg_lambda': 8.754578290405185, 'scale_pos_weight': 8.928228346414862, 'subsample': 0.6091506503226419, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9600
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5466
# Loss (1 - Recall_1): 0.4534, Duration: 53.89s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9727282
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.7045380096317659, 'colsample_bynode': 0.6585773139369596, 'colsample_bytree': 0.7068905824555384, 'device': 'cuda', 'gamma': 0.9946803254024538, 'learning_rate': 0.0483147786704909, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 600, 'random_state': 0, 'reg_alpha': 0.0010985477501850823, 'reg_lambda': 5.134355358960442, 'scale_pos_weight': 11.793976734866472, 'subsample': 0.5032484645755999, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9727
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5513
# Loss (1 - Recall_1): 0.4487, Duration: 20.02s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9307842
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.9575265814412787, 'colsample_bynode': 0.5109050880688819, 'colsample_bytree': 0.5589720085336274, 'device': 'cuda', 'gamma': 0.09162948619447718, 'learning_rate': 0.11811318491983758, 'max_depth': 7, 'min_child_weight': 8, 'n_estimators': 850, 'random_state': 0, 'reg_alpha': 0.006533962534435817, 'reg_lambda': 8.170457289870821, 'scale_pos_weight': 4.474516060105176, 'subsample': 0.6993073486393633, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9308
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5450
# Loss (1 - Recall_1): 0.4550, Duration: 30.32s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9446945
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.6332416487783266, 'colsample_bynode': 0.7081858159874402, 'colsample_bytree': 0.7529840193311256, 'device': 'cuda', 'gamma': 0.5421631833968723, 'learning_rate': 0.06505807908888198, 'max_depth': 7, 'min_child_weight': 9, 'n_estimators': 800, 'random_state': 0, 'reg_alpha': 0.03375410614363356, 'reg_lambda': 3.78694158116293, 'scale_pos_weight': 6.134095896009818, 'subsample': 0.8137655152673947, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9447
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5478
# Loss (1 - Recall_1): 0.4522, Duration: 29.17s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9135186
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.7548731313769006, 'colsample_bynode': 0.6258166241370343, 'colsample_bytree': 0.6166197987845532, 'device': 'cuda', 'gamma': 0.6650087923092227, 'learning_rate': 0.01413393778942032, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 500, 'random_state': 0, 'reg_alpha': 0.07480800859534333, 'reg_lambda': 9.219213934187849, 'scale_pos_weight': 3.829967639898649, 'subsample': 0.7511111885235401, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9135
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5492
# Loss (1 - Recall_1): 0.4508, Duration: 18.40s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9540220
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.8121103637352864, 'colsample_bynode': 0.7623694888646253, 'colsample_bytree': 0.7599689163225458, 'device': 'cuda', 'gamma': 0.3831022557155507, 'learning_rate': 0.29619239016188353, 'max_depth': 7, 'min_child_weight': 7, 'n_estimators': 600, 'random_state': 0, 'reg_alpha': 0.0016567271226281273, 'reg_lambda': 5.419200278467974, 'scale_pos_weight': 2.8063848354320777, 'subsample': 0.5497943951469957, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9540
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.4966
# Loss (1 - Recall_1): 0.5034, Duration: 24.17s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9385209
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.5859538582202195, 'colsample_bynode': 0.8241450521877711, 'colsample_bytree': 0.5901077618082158, 'device': 'cuda', 'gamma': 0.9317437765893974, 'learning_rate': 0.11715415309818217, 'max_depth': 6, 'min_child_weight': 1, 'n_estimators': 950, 'random_state': 0, 'reg_alpha': 0.013452263605379747, 'reg_lambda': 7.375629940272315, 'scale_pos_weight': 5.148411991243661, 'subsample': 0.6782411147785308, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9385
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5427
# Loss (1 - Recall_1): 0.4573, Duration: 26.51s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.8773124
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.8627193058415121, 'colsample_bynode': 0.5816472838151705, 'colsample_bytree': 0.6538585453109312, 'device': 'cuda', 'gamma': 0.833968036193908, 'learning_rate': 0.036189076844303114, 'max_depth': 7, 'min_child_weight': 10, 'n_estimators': 300, 'random_state': 0, 'reg_alpha': 0.003863429983549168, 'reg_lambda': 6.444870685401325, 'scale_pos_weight': 2.3221925226452313, 'subsample': 0.7246286633106969, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.8773
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5539
# Loss (1 - Recall_1): 0.4461, Duration: 13.78s
# ...
# Loss (1 - Recall_1): 0.4511, Duration: 31.57s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9657276
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.7684261756305191, 'colsample_bynode': 0.9224304032369453, 'colsample_bytree': 0.8204784760725032, 'device': 'cuda', 'gamma': 0.6721085854102125, 'learning_rate': 0.2624046708887672, 'max_depth': 5, 'min_child_weight': 7, 'n_estimators': 650, 'random_state': 0, 'reg_alpha': 0.005671762809217958, 'reg_lambda': 6.097987595330754, 'scale_pos_weight': 7.181934830584601, 'subsample': 0.6828446535982817, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9657
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5232
# Loss (1 - Recall_1): 0.4768, Duration: 23.11s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9726747
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.7961221227757773, 'colsample_bynode': 0.7378826240497419, 'colsample_bytree': 0.6175567002123156, 'device': 'cuda', 'gamma': 0.799268567725204, 'learning_rate': 0.020746147074075745, 'max_depth': 7, 'min_child_weight': 8, 'n_estimators': 300, 'random_state': 0, 'reg_alpha': 0.1128483436580352, 'reg_lambda': 5.765867523596013, 'scale_pos_weight': 13.948208035421745, 'subsample': 0.5380675832463663, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9727
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5450
# Loss (1 - Recall_1): 0.4550, Duration: 21.16s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9688486
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.8518977571488311, 'colsample_bynode': 0.8486282723035083, 'colsample_bytree': 0.7299529500685552, 'device': 'cuda', 'gamma': 0.1339802859669176, 'learning_rate': 0.10810700534284015, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 700, 'random_state': 0, 'reg_alpha': 0.027991271534257515, 'reg_lambda': 6.603242919022559, 'scale_pos_weight': 11.539775764902238, 'subsample': 0.5696337403402357, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9688
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5483
# Loss (1 - Recall_1): 0.4517, Duration: 39.68s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9589262
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.6941862279359957, 'colsample_bynode': 0.7770964663095612, 'colsample_bytree': 0.7658940774221858, 'device': 'cuda', 'gamma': 0.3257234812102985, 'learning_rate': 0.038079023915907784, 'max_depth': 6, 'min_child_weight': 6, 'n_estimators': 450, 'random_state': 0, 'reg_alpha': 0.001216257212937416, 'reg_lambda': 3.5174017080868194, 'scale_pos_weight': 7.796863711259954, 'subsample': 0.5535989928580602, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9589
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5505
# Loss (1 - Recall_1): 0.4495, Duration: 20.95s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.7743462
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.8133081592047458, 'colsample_bynode': 0.5687612868754021, 'colsample_bytree': 0.8418532674460604, 'device': 'cuda', 'gamma': 0.17949478878588493, 'learning_rate': 0.07580971924898032, 'max_depth': 7, 'min_child_weight': 7, 'n_estimators': 400, 'random_state': 0, 'reg_alpha': 0.19268081278571386, 'reg_lambda': 7.543302164708781, 'scale_pos_weight': 1.0049326505823235, 'subsample': 0.599114775793449, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.7743
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5579
# Loss (1 - Recall_1): 0.4421, Duration: 23.41s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9813281
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.8853622869859789, 'colsample_bynode': 0.8979408713863126, 'colsample_bytree': 0.7547076930404641, 'device': 'cuda', 'gamma': 0.2253423167414647, 'learning_rate': 0.046095988477277285, 'max_depth': 5, 'min_child_weight': 6, 'n_estimators': 1000, 'random_state': 0, 'reg_alpha': 0.011545718587649896, 'reg_lambda': 6.907573042497316, 'scale_pos_weight': 17.46443243928045, 'subsample': 0.6525247353224184, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9813
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5572
# Loss (1 - Recall_1): 0.4428, Duration: 30.38s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9654828
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.6170418305902442, 'colsample_bynode': 0.8022801096142447, 'colsample_bytree': 0.8767255359673002, 'device': 'cuda', 'gamma': 0.7535792931628895, 'learning_rate': 0.03360118547388833, 'max_depth': 6, 'min_child_weight': 9, 'n_estimators': 900, 'random_state': 0, 'reg_alpha': 0.00425642478029087, 'reg_lambda': 8.648891552557357, 'scale_pos_weight': 9.346116123487773, 'subsample': 0.6224991990535124, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9655
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5534
# Loss (1 - Recall_1): 0.4466, Duration: 35.26s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.8866196
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.710884762162169, 'colsample_bynode': 0.5146991763378627, 'colsample_bytree': 0.6911482025283231, 'device': 'cuda', 'gamma': 0.2823308576158299, 'learning_rate': 0.012729072151685717, 'max_depth': 7, 'min_child_weight': 8, 'n_estimators': 800, 'random_state': 0, 'reg_alpha': 0.07272457880570685, 'reg_lambda': 9.767105761483432, 'scale_pos_weight': 2.548470003893302, 'subsample': 0.6365982167304252, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.8866
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5504
# Loss (1 - Recall_1): 0.4496, Duration: 43.48s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9155688
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.7734059313373143, 'colsample_bynode': 0.7549583944236209, 'colsample_bytree': 0.5219488514699028, 'device': 'cuda', 'gamma': 0.06320754710465787, 'learning_rate': 0.0101915892602108, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 350, 'random_state': 0, 'reg_alpha': 0.019891942543568384, 'reg_lambda': 5.584279535917116, 'scale_pos_weight': 5.555318863267209, 'subsample': 0.5001877314283723, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9156
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5099
# Loss (1 - Recall_1): 0.4901, Duration: 13.57s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9522895
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.6651340803594369, 'colsample_bynode': 0.7630504785177232, 'colsample_bytree': 0.9946426476115717, 'device': 'cuda', 'gamma': 0.618299308060789, 'learning_rate': 0.04218468961119499, 'max_depth': 6, 'min_child_weight': 3, 'n_estimators': 600, 'random_state': 0, 'reg_alpha': 0.009134251196494159, 'reg_lambda': 5.9528860435246775, 'scale_pos_weight': 6.775964832533004, 'subsample': 0.5783151529062757, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9523
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5594
# Loss (1 - Recall_1): 0.4406, Duration: 26.15s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9002883
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.5167211869520549, 'colsample_bynode': 0.5972248385721001, 'colsample_bytree': 0.7207261766679991, 'device': 'cuda', 'gamma': 0.9974684709748678, 'learning_rate': 0.007529890791430866, 'max_depth': 7, 'min_child_weight': 7, 'n_estimators': 750, 'random_state': 0, 'reg_alpha': 0.0017869866934355336, 'reg_lambda': 7.227775155012596, 'scale_pos_weight': 3.3910347161833787, 'subsample': 0.6080959634571349, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9003
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5475
# Loss (1 - Recall_1): 0.4525, Duration: 44.41s
# ------------------------------
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9631734
# Achieved Recall at Threshold: 0.9800
# Trial Params: {'colsample_bylevel': 0.6016555962680908, 'colsample_bynode': 0.6365585704176381, 'colsample_bytree': 0.5456357290035317, 'device': 'cuda', 'gamma': 0.6944314855499936, 'learning_rate': 0.05008230231076136, 'max_depth': 3, 'min_child_weight': 4, 'n_estimators': 950, 'random_state': 0, 'reg_alpha': 0.001414197959698996, 'reg_lambda': 6.287567324542227, 'scale_pos_weight': 8.301137283191377, 'subsample': 0.5087803985258175, 'tree_method': 'hist'}
# Constraint Met: True
#   Threshold: 0.9632
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Recall Class 1 (Maximized): 0.5558
# Loss (1 - Recall_1): 0.4442, Duration: 20.27s
# ------------------------------
# 100%|██████████| 100/100 [48:32<00:00, 29.13s/trial, best loss: 0.4366434238999759]
#
# ==============================
# Hyperparameter Tuning Complete!
# Best Parameters Found (raw): {'colsample_bylevel': 0.7034102067004069, 'colsample_bynode': 0.8390472679574996, 'colsample_bytree': 0.6579388820591151, 'gamma': 0.8748685189195721, 'learning_rate': 0.03865122131423628, 'max_depth': 6.0, 'min_child_weight': 6.0, 'n_estimators': 800.0, 'reg_alpha': 0.01227859576937017, 'reg_lambda': 8.80210770131299, 'scale_pos_weight': 3.936315894379681, 'subsample': 0.6258062584859616}
# Best Parameters Found (evaluated): {'colsample_bylevel': 0.7034102067004069, 'colsample_bynode': 0.8390472679574996, 'colsample_bytree': 0.6579388820591151, 'device': 'cuda', 'gamma': 0.8748685189195721, 'learning_rate': 0.03865122131423628, 'max_depth': 6.0, 'min_child_weight': 6.0, 'n_estimators': 800.0, 'random_state': 0, 'reg_alpha': 0.01227859576937017, 'reg_lambda': 8.80210770131299, 'scale_pos_weight': 3.936315894379681, 'subsample': 0.6258062584859616, 'tree_method': 'hist'}
#
# Best Trial Results:
#   Loss (1 - Recall Class 1): 0.4366
#   Recall Class 1 (Maximized): 0.5634
#   Recall Class 0 (Constraint >= 0.98): 0.9800
#   Threshold Used: 0.9199535846710205
# ==============================

# %%
best_hyperparameters
# Out:
# {'colsample_bylevel': 0.7034102067004069,
#  'colsample_bynode': 0.8390472679574996,
#  'colsample_bytree': 0.6579388820591151,
#  'device': 'cuda',
#  'gamma': 0.8748685189195721,
#  'learning_rate': 0.03865122131423628,
#  'max_depth': 6.0,
#  'min_child_weight': 6.0,
#  'n_estimators': 800.0,
#  'random_state': 0,
#  'reg_alpha': 0.01227859576937017,
#  'reg_lambda': 8.80210770131299,
#  'scale_pos_weight': 3.936315894379681,
#  'subsample': 0.6258062584859616,
#  'tree_method': 'hist'}

# %%
best_hyperparameters['max_depth'] = int(best_hyperparameters['max_depth'])
best_hyperparameters['n_estimators'] = int(best_hyperparameters['n_estimators'])

# %%
from utils.mlflow_ml_model_logger import log_classification_model

# %%
model = XGBClassifier(**best_hyperparameters)
log_classification_model(
        model=model,
        X_train=train_df.drop(columns=['customer_ID']),
        y_train=y_train['target'].values,
        X_val=test_df.drop(columns=['customer_ID']),
        y_val=y_test['target'].values,
        run_name="XGBoost HP Tuned - Test"
    )
# Out:
# Starting MLflow Run: XGBoost HP Tuned - Test (baa0e70cab594b94acb26781c9c2900d)
# Logged model parameters.
# Training the model...
# Model training complete.
# Evaluating the model on the validation set...
# Attempting to find custom threshold using find_threshold_binary_search for Recall[0] >= 0.9800
# Target Recall: >= 0.9800 for Class 0
# Threshold found by Binary Search: 0.9209796
# Achieved Recall at Threshold: 0.9800
# Using threshold: Custom threshold 0.9210 aiming for Recall[0] >= 0.9800 (func achieved 0.9800)
# Calculating performance metrics...
# Validation Accuracy: 0.8700
# Validation Weighted F1-Score: 0.8585
# Validation Macro F1-Score: 0.8033
# Validation Recall Class 0: 0.9800
# Validation Recall Class 1: 0.5553
# Validation Precision Class 0: 0.8631
# Validation Precision Class 1: 0.9066
#
#               precision    recall  f1-score   support
#
#            0     0.8631    0.9800    0.9179    102026
#            1     0.9066    0.5553    0.6887     35648
#
#     accuracy                         0.8700    137674
#    macro avg     0.8849    0.7676    0.8033    137674
# weighted avg     0.8744    0.8700    0.8585    137674
#
# Logged validation metrics (rounded to 4 decimals).
# Generating Confusion Matrix plot...
# Saved Confusion Matrix plot to: confusion_matrix_val.png
# Displayed Confusion Matrix plot.
# Logged Confusion Matrix plot artifact.
# Logging classification report artifact...
# Logged classification report artifact: classification_report_val.json
# Logging the model...
# 2025/04/17 13:19:03 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Logged the trained model using mlflow.sklearn.
# MLflow Run completed: baa0e70cab594b94acb26781c9c2900d
# View the run in the MLflow UI.
